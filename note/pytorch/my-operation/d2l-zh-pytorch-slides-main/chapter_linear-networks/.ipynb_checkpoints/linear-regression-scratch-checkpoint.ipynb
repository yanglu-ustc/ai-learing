# %% [markdown]
# # 线性回归的从零开始实现
#
# 我们将从零开始实现整个方法，
# 包括数据流水线、模型、损失函数和小批量随机梯度下降优化器

# %%
# %matplotlib inline
import random
import torch
from d2l import torch as d2l

# %% [markdown]
# 根据带有噪声的线性模型构造一个人造数据集。
# 我们使用线性模型参数$\mathbf{w} = [2, -3.4]^\top$、$b = 4.2$
# 和噪声项$\epsilon$生成数据集及其标签：
#
# $$\mathbf{y}= \mathbf{X} \mathbf{w} + b + \mathbf\epsilon$$

# %%
def synthetic_data(w, b, num_examples):  
    """生成y=Xw+b+噪声"""
    # 0是均值，方差为1，num_examples表示的是样本个数
    X = torch.normal(0, 1, (num_examples, len(w)))
    # torch.mm用于两个二维矩阵之间的矩阵乘法操作，只能用于二维情况。
    # torch.matmul用于多个张量之间的矩阵乘法操作，可以处理多个张量之间的批量矩阵乘法和高维张量之间的矩阵乘法。
    y = torch.matmul(X, w) + b
    # 0是均值，方差为1，y.shape表示的是和y的shape一致，这是一个噪音！！！！！！！
    y += torch.normal(0, 0.01, y.shape)
    # reshape函数中-1代表的是n，什么意思呢，函数中另一个参数决定了-1的值
    # 定义(3,4)的张量，reshape(-1, 1)，你把它想象成要转换成(n,1)的矩阵，那是多少？没错，最后转换成了12*1的矩阵，reshape(1, -1)呢？那就是1*12了
    return X, y.reshape((-1, 1))

true_w = torch.tensor([2, -3.4])
# true_w = torch.tensor([-100, -3.4])
print(true_w.shape)
true_b = 4.2
features, labels = synthetic_data(true_w, true_b, 1000)
print(features.shape)
# Out:
# torch.Size([2])
# torch.Size([1000, 2])

# %% [markdown]
# `features`中的每一行都包含一个二维数据样本，
# `labels`中的每一行都包含一维标签值（一个标量）

# %%
print('features:', features[0],'\nlabel:', labels[0])
print(features)
print(len(features))
# Out:
# features: tensor([-0.5293, -0.9212])
# label: tensor([6.2684])
# tensor([[-0.5293, -0.9212],
#         [ 2.1521,  2.2492],
#         [ 1.3845,  2.0144],
#         ...,
#         [-1.7486,  1.7310],
#         [ 0.4291,  0.2378],
#         [ 0.9914,  0.1737]])
# 1000

# %%
d2l.set_figsize()

# tensor.detach():
# 从计算图中脱离出来，返回一个新的tensor，新的tensor和原tensor共享数据内存（这也就意味着修改一个tensor的值，另外一个也会改变），但是不涉及梯度计算
# 在从tensor转换成为numpy的时候，如果转换前面的tensor在计算图里面（requires_grad = True），那么这个时候只能先进行detach操作才能转换成为numpy
d2l.plt.scatter(features[:, (1)].detach().numpy(), labels.detach().numpy(), 1);

# %%
d2l.set_figsize()
d2l.plt.scatter(features[:, (0)].detach().numpy(), labels.detach().numpy(), 1);

# %% [markdown]
# 定义一个`data_iter`函数，
# 该函数接收批量大小、特征矩阵和标签向量作为输入，生成大小为`batch_size`的小批量

# %%
def data_iter(batch_size, features, labels):
    num_examples = len(features)
    indices = list(range(num_examples))
    #  random.shuffle()用于将一个列表中的元素打乱顺序，值得注意的是使用这个方法不会生成新的列表，只是将原列表的次序打乱
    random.shuffle(indices)
    for i in range(0, num_examples, batch_size):
        batch_indices = torch.tensor(
            indices[i: min(i + batch_size, num_examples)])
        yield features[batch_indices], labels[batch_indices]

batch_size = 10

for X, y in data_iter(batch_size, features, labels):
    print(X, '\n', y)
    break
# Out:
# tensor([[-3.1067, -1.3648],
#         [-0.2357, -1.4652],
#         [-0.5159,  0.2499],
#         [-0.4984,  0.7777],
#         [ 0.0321, -1.3568],
#         [ 2.0721, -1.1734],
#         [-0.8169,  0.5563],
#         [-1.4103,  0.6104],
#         [ 1.6500,  0.1640],
#         [ 0.6453, -2.3559]])
#  tensor([[ 2.6223],
#         [ 8.7185],
#         [ 2.3273],
#         [ 0.5793],
#         [ 8.8772],
#         [12.3413],
#         [ 0.6749],
#         [-0.6927],
#         [ 6.9286],
#         [13.5245]])

# %% [markdown]
# 在我们开始用小批量随机梯度下降优化我们的模型参数之前
# 我们需要先有一些参数

# %%
w = torch.normal(0, 0.01, size=(2,1), requires_grad=True)
b = torch.zeros(1, requires_grad=True)
print(w)
print(b)
# Out:
# tensor([[-0.0005],
#         [ 0.0100]], requires_grad=True)
# tensor([0.], requires_grad=True)

# %% [markdown]
# 定义模型，将模型的输入和参数同模型的输出关联起来

# %%
def linreg(X, w, b):  
    """线性回归模型"""
    return torch.matmul(X, w) + b

# %% [markdown]
# 定义损失函数

# %%
def squared_loss(y_hat, y):  
    """均方损失"""
    return (y_hat - y.reshape(y_hat.shape)) ** 2 / 2

# %% [markdown]
# 定义优化算法

# %%
# lr：表示的是学习率
def sgd(params, lr, batch_size):  
    """小批量随机梯度下降"""
    # 当你在 torch.no_grad() 上下文管理器中执行张量操作时，PyTorch 不会为这些操作计算梯度。这意味着不会在 .grad 属性中累积梯度，并且操作会更快地执行。
    with torch.no_grad():
        for param in params:
            param -= lr * param.grad / batch_size
            # 手动将梯度设为 0
            param.grad.zero_()

# %% [markdown]
# 训练过程

# %%
lr = 0.03
# 进行训练的次数
num_epochs = 3
net = linreg
loss = squared_loss

for epoch in range(num_epochs):
    for X, y in data_iter(batch_size, features, labels):
        l = loss(net(X, w, b), y)
        # 梯度计算
        l.sum().backward()
        sgd([w, b], lr, batch_size)
    with torch.no_grad():
        # 输出测试结果
        train_l = loss(net(features, w, b), labels)
        print(f'epoch {epoch + 1}, loss {float(train_l.mean()):f}')
# Out:
# epoch 1, loss 0.043864
# epoch 2, loss 0.000172
# epoch 3, loss 0.000051

# %% [markdown]
# 比较真实参数和通过训练学到的参数来评估训练的成功程度

# %%
print(f'w的估计误差: {true_w - w.reshape(true_w.shape)}')
print(f'b的估计误差: {true_b - b}')
# Out:
# w的估计误差: tensor([ 0.0004, -0.0001], grad_fn=<SubBackward0>)
# b的估计误差: tensor([0.0007], grad_fn=<RsubBackward1>)
